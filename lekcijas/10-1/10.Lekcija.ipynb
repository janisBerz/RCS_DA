# %%
import pandas as pd
import numpy as np
import sys
import os

# %%
pd.options.display.max_columns = 20
pd.options.display.max_rows = 3

# %%
csv_file = "https://data.gov.lv/dati/dataset/e909312a-61c9-4cde-a72a-0a09dd75ef43/resource/d01a32c6-add8-4b8d-a013-0c35a3879564/download/eis_e_iepirkumi_rezultati_2021.csv"
df = pd.read_csv(csv_file,sep=';')

# %%
df
# Out:
#       Iepirkuma_ID                                Iepirkuma_nosaukums  \
# 0          ="9246"   ="Būvniecības dokumentācijas izstrāde ielu, a...
# ...            ...                                                ...
# 36351     ="68351"                          ="SAP licenču uzturēšana"
#
#        Iepirkuma_identifikacijas_numurs          Pasutitaja_nosaukums  \
# 0                       ="DPD 2017/123"   ="Daugavpils pilsētas dome"
# ...                                 ...                           ...
# 36351                     ="VK 2021/07"                ="Valsts kase"
#
#        Pasutitaja_registracijas_numurs  \
# 0                       ="90000077325"
# ...                                ...
# 36351                   ="90000597275"
#
#                    Pasutitaja_registracijas_numura_veids  Pasutitaja_PVS_ID  \
# 0       ="Personas kods/nodokļu maksātāja reģistrācij...           ="22678"
# ...                                                  ...                ...
# ...

# %%
df.columns
# Out:
# Index(['Iepirkuma_ID', ' Iepirkuma_nosaukums',
#        ' Iepirkuma_identifikacijas_numurs', ' Pasutitaja_nosaukums',
#        ' Pasutitaja_registracijas_numurs',
#        ' Pasutitaja_registracijas_numura_veids', ' Pasutitaja_PVS_ID',
#        ' Augstak_stavosa_organizacija', ' Iepirkuma_statuss',
#        ' Regulejasais_tiesibu_akts', ' Proceduras_veids',
#        ' Hipersaite_EIS_kura_pieejams_zinojums',
#        ' Hipersaite_uz_IUB_publikaciju', ' Ir_dalijums_dalas',
#        ' Iepirkuma_dalas_nr', ' Iepirkuma_dalas_nosaukums',
#        ' Iepirkuma_dalas_statuss', ' Uzvaretaja_nosaukums',
#        ' Uzvaretaja_registracijas_numurs',
#        ' Uzvaretaja_registracijas_numura_veids', ' Uzvaretaja_valsts',
#        ' Liguma_dok_veids', ' Noslegta_liguma_dok_ID', ' Saistita_liguma_ID',
#        ' Aktuala_liguma_summa', ' Aktuala_liguma_summas_valuta',
#        ' Sakotneja_liguma_summa', ' Sakotneja_liguma_summas_valuta',
#        ' Liguma_izpildes_termins', ' Liguma_izpilde_no',
# ...

# %%
df = df[['Iepirkuma_ID',' Iepirkuma_nosaukums',' Iepirkuma_identifikacijas_numurs',' Pasutitaja_nosaukums',' Pasutitaja_registracijas_numurs',' Pasutitaja_registracijas_numura_veids',' Uzvaretaja_nosaukums',' Uzvaretaja_registracijas_numurs',' Uzvaretaja_registracijas_numura_veids',' Uzvaretaja_valsts',' Aktuala_liguma_summa',' Aktuala_liguma_summas_valuta',' Sakotneja_liguma_summa',' Sakotneja_liguma_summas_valuta',' Liguma_izpilde_no',' Liguma_izpilde_līdz']]

# %%
df.columns
# Out:
# Index(['Iepirkuma_ID', ' Iepirkuma_nosaukums',
#        ' Iepirkuma_identifikacijas_numurs', ' Pasutitaja_nosaukums',
#        ' Pasutitaja_registracijas_numurs',
#        ' Pasutitaja_registracijas_numura_veids', ' Uzvaretaja_nosaukums',
#        ' Uzvaretaja_registracijas_numurs',
#        ' Uzvaretaja_registracijas_numura_veids', ' Uzvaretaja_valsts',
#        ' Aktuala_liguma_summa', ' Aktuala_liguma_summas_valuta',
#        ' Sakotneja_liguma_summa', ' Sakotneja_liguma_summas_valuta',
#        ' Liguma_izpilde_no', ' Liguma_izpilde_līdz'],
#       dtype='object')

# %%
df
# Out:
#       Iepirkuma_ID                                Iepirkuma_nosaukums  \
# 0          ="9246"   ="Būvniecības dokumentācijas izstrāde ielu, a...
# ...            ...                                                ...
# 36351     ="68351"                          ="SAP licenču uzturēšana"
#
#        Iepirkuma_identifikacijas_numurs          Pasutitaja_nosaukums  \
# 0                       ="DPD 2017/123"   ="Daugavpils pilsētas dome"
# ...                                 ...                           ...
# 36351                     ="VK 2021/07"                ="Valsts kase"
#
#        Pasutitaja_registracijas_numurs  \
# 0                       ="90000077325"
# ...                                ...
# 36351                   ="90000597275"
#
#                    Pasutitaja_registracijas_numura_veids  \
# 0       ="Personas kods/nodokļu maksātāja reģistrācij...
# ...                                                  ...
# 36351   ="Personas kods/nodokļu maksātāja reģistrācij...
#
# ...

# %%
df = df.applymap(lambda x: x.replace('=','').replace('"','').strip())
# Out:
# C:\Users\artur\AppData\Local\Temp\ipykernel_25420\3112674669.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.replace('=','').replace('"','').strip())

# %%
df
# Out:
#       Iepirkuma_ID                                Iepirkuma_nosaukums  \
# 0             9246  Būvniecības dokumentācijas izstrāde ielu, auto...
# ...            ...                                                ...
# 36351        68351                             SAP licenču uzturēšana
#
#        Iepirkuma_identifikacijas_numurs      Pasutitaja_nosaukums  \
# 0                          DPD 2017/123  Daugavpils pilsētas dome
# ...                                 ...                       ...
# 36351                        VK 2021/07               Valsts kase
#
#        Pasutitaja_registracijas_numurs  \
# 0                          90000077325
# ...                                ...
# 36351                      90000597275
#
#                    Pasutitaja_registracijas_numura_veids  \
# 0      Personas kods/nodokļu maksātāja reģistrācijas ...
# ...                                                  ...
# 36351  Personas kods/nodokļu maksātāja reģistrācijas ...
#
# ...

# %%
df.columns = df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['Iepirkuma_ID', 'Iepirkuma_nosaukums',
#        'Iepirkuma_identifikacijas_numurs', 'Pasutitaja_nosaukums',
#        'Pasutitaja_registracijas_numurs',
#        'Pasutitaja_registracijas_numura_veids', 'Uzvaretaja_nosaukums',
#        'Uzvaretaja_registracijas_numurs',
#        'Uzvaretaja_registracijas_numura_veids', 'Uzvaretaja_valsts',
#        'Aktuala_liguma_summa', 'Aktuala_liguma_summas_valuta',
#        'Sakotneja_liguma_summa', 'Sakotneja_liguma_summas_valuta',
#        'Liguma_izpilde_no', 'Liguma_izpilde_līdz'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36352 entries, 0 to 36351
# Data columns (total 16 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Iepirkuma_ID                           36352 non-null  object
#  1   Iepirkuma_nosaukums                    36352 non-null  object
#  2   Iepirkuma_identifikacijas_numurs       36352 non-null  object
#  3   Pasutitaja_nosaukums                   36352 non-null  object
#  4   Pasutitaja_registracijas_numurs        36352 non-null  object
#  5   Pasutitaja_registracijas_numura_veids  36352 non-null  object
#  6   Uzvaretaja_nosaukums                   36352 non-null  object
#  7   Uzvaretaja_registracijas_numurs        36352 non-null  object
#  8   Uzvaretaja_registracijas_numura_veids  36352 non-null  object
#  9   Uzvaretaja_valsts                      36352 non-null  object
# ...

# %%
df = df.replace(to_replace="",value = np.nan)

# %%
df
# Out:
#       Iepirkuma_ID                                Iepirkuma_nosaukums  \
# 0             9246  Būvniecības dokumentācijas izstrāde ielu, auto...
# ...            ...                                                ...
# 36351        68351                             SAP licenču uzturēšana
#
#       Iepirkuma_identifikacijas_numurs      Pasutitaja_nosaukums  \
# 0                         DPD 2017/123  Daugavpils pilsētas dome
# ...                                ...                       ...
# 36351                       VK 2021/07               Valsts kase
#
#       Pasutitaja_registracijas_numurs  \
# 0                         90000077325
# ...                               ...
# 36351                     90000597275
#
#                    Pasutitaja_registracijas_numura_veids  \
# 0      Personas kods/nodokļu maksātāja reģistrācijas ...
# ...                                                  ...
# 36351  Personas kods/nodokļu maksātāja reģistrācijas ...
#
# ...

# %%
df = df.astype({'Iepirkuma_ID':int,'Aktuala_liguma_summa':float,'Sakotneja_liguma_summa':float})

# %%
df
# Out:
#        Iepirkuma_ID                                Iepirkuma_nosaukums  \
# 0              9246  Būvniecības dokumentācijas izstrāde ielu, auto...
# ...             ...                                                ...
# 36351         68351                             SAP licenču uzturēšana
#
#       Iepirkuma_identifikacijas_numurs      Pasutitaja_nosaukums  \
# 0                         DPD 2017/123  Daugavpils pilsētas dome
# ...                                ...                       ...
# 36351                       VK 2021/07               Valsts kase
#
#       Pasutitaja_registracijas_numurs  \
# 0                         90000077325
# ...                               ...
# 36351                     90000597275
#
#                    Pasutitaja_registracijas_numura_veids  \
# 0      Personas kods/nodokļu maksātāja reģistrācijas ...
# ...                                                  ...
# 36351  Personas kods/nodokļu maksātāja reģistrācijas ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36352 entries, 0 to 36351
# Data columns (total 16 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Iepirkuma_ID                           36352 non-null  int32
#  1   Iepirkuma_nosaukums                    36352 non-null  object
#  2   Iepirkuma_identifikacijas_numurs       36352 non-null  object
#  3   Pasutitaja_nosaukums                   36352 non-null  object
#  4   Pasutitaja_registracijas_numurs        36352 non-null  object
#  5   Pasutitaja_registracijas_numura_veids  36352 non-null  object
#  6   Uzvaretaja_nosaukums                   36352 non-null  object
#  7   Uzvaretaja_registracijas_numurs        35924 non-null  object
#  8   Uzvaretaja_registracijas_numura_veids  34524 non-null  object
#  9   Uzvaretaja_valsts                      34952 non-null  object
# ...

# %%
df.Liguma_izpilde_no = pd.to_datetime(df.Liguma_izpilde_no,dayfirst = True,errors = 'coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36352 entries, 0 to 36351
# Data columns (total 16 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Iepirkuma_ID                           36352 non-null  int32
#  1   Iepirkuma_nosaukums                    36352 non-null  object
#  2   Iepirkuma_identifikacijas_numurs       36352 non-null  object
#  3   Pasutitaja_nosaukums                   36352 non-null  object
#  4   Pasutitaja_registracijas_numurs        36352 non-null  object
#  5   Pasutitaja_registracijas_numura_veids  36352 non-null  object
#  6   Uzvaretaja_nosaukums                   36352 non-null  object
#  7   Uzvaretaja_registracijas_numurs        35924 non-null  object
#  8   Uzvaretaja_registracijas_numura_veids  34524 non-null  object
#  9   Uzvaretaja_valsts                      34952 non-null  object
# ...

# %%
df.Liguma_izpilde_no.value_counts()
# Out:
# Liguma_izpilde_no
# 2022-01-01    162
#              ...
# 2022-02-01      1
# Name: count, Length: 374, dtype: int64

# %%
df.Liguma_izpilde_līdz = pd.to_datetime(df.Liguma_izpilde_līdz,dayfirst=True,errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36352 entries, 0 to 36351
# Data columns (total 16 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Iepirkuma_ID                           36352 non-null  int32
#  1   Iepirkuma_nosaukums                    36352 non-null  object
#  2   Iepirkuma_identifikacijas_numurs       36352 non-null  object
#  3   Pasutitaja_nosaukums                   36352 non-null  object
#  4   Pasutitaja_registracijas_numurs        36352 non-null  object
#  5   Pasutitaja_registracijas_numura_veids  36352 non-null  object
#  6   Uzvaretaja_nosaukums                   36352 non-null  object
#  7   Uzvaretaja_registracijas_numurs        35924 non-null  object
#  8   Uzvaretaja_registracijas_numura_veids  34524 non-null  object
#  9   Uzvaretaja_valsts                      34952 non-null  object
# ...

# %%
# pārbaudīt duplikātus
df[df.duplicated()]
# Out:
#        Iepirkuma_ID                                Iepirkuma_nosaukums  \
# 3              9449  Augsnes gatavošanas un meža dabiskās atjaunoša...
# ...             ...                                                ...
# 36305         67418  Mazlietota automobiļa  piegāde Nautrēnu apvien...
#
#       Iepirkuma_identifikacijas_numurs  \
# 3             AS LVM MS MK_2017_417_Ak
# ...                                ...
# 36305                      NAP 2021/22
#
#                                     Pasutitaja_nosaukums  \
# 3                                   Latvijas valsts meži
# ...                                                  ...
# 36305  Rēzeknes novada pašvaldības iestāde 'Nautrēnu ...
#
#       Pasutitaja_registracijas_numurs  \
# 3                         40003466281
# ...                               ...
# 36305                     40900027430
#
#                    Pasutitaja_registracijas_numura_veids Uzvaretaja_nosaukums  \
# ...

# %%
df[df.duplicated(subset = ['Pasutitaja_nosaukums', 'Pasutitaja_registracijas_numurs'],keep='first')]
# Out:
#        Iepirkuma_ID                                Iepirkuma_nosaukums  \
# 3              9449  Augsnes gatavošanas un meža dabiskās atjaunoša...
# ...             ...                                                ...
# 36351         68351                             SAP licenču uzturēšana
#
#       Iepirkuma_identifikacijas_numurs  Pasutitaja_nosaukums  \
# 3             AS LVM MS MK_2017_417_Ak  Latvijas valsts meži
# ...                                ...                   ...
# 36351                       VK 2021/07           Valsts kase
#
#       Pasutitaja_registracijas_numurs  \
# 3                         40003466281
# ...                               ...
# 36351                     90000597275
#
#                    Pasutitaja_registracijas_numura_veids Uzvaretaja_nosaukums  \
# 3      Personas kods/nodokļu maksātāja reģistrācijas ...      'Kursa MRU' SIA
# ...                                                  ...                  ...
# ...

# %%
df = df.drop_duplicates().reset_index(drop = True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Iepirkuma_ID, Iepirkuma_nosaukums, Iepirkuma_identifikacijas_numurs, Pasutitaja_nosaukums, Pasutitaja_registracijas_numurs, Pasutitaja_registracijas_numura_veids, Uzvaretaja_nosaukums, Uzvaretaja_registracijas_numurs, Uzvaretaja_registracijas_numura_veids, Uzvaretaja_valsts, Aktuala_liguma_summa, Aktuala_liguma_summas_valuta, Sakotneja_liguma_summa, Sakotneja_liguma_summas_valuta, Liguma_izpilde_no, Liguma_izpilde_līdz]
# Index: []

# %%
# df.columns
df.Aktuala_liguma_summas_valuta.value_counts()
# Out:
# Aktuala_liguma_summas_valuta
# EUR     23232
# LATI        6
# Name: count, dtype: int64

# %%
v = {'EUR':1, 'LATI':0}
df.loc[:,'is_EUR'] = df.Aktuala_liguma_summas_valuta.map(v)

# %%
df.head(10)
# Out:
#     Iepirkuma_ID                                Iepirkuma_nosaukums  \
# 0           9246  Būvniecības dokumentācijas izstrāde ielu, auto...
# ..           ...                                                ...
# 9           9641  Elektroenerģijas piegāde Jelgavas pilsētas paš...
#
#    Iepirkuma_identifikacijas_numurs      Pasutitaja_nosaukums  \
# 0                      DPD 2017/123  Daugavpils pilsētas dome
# ..                              ...                       ...
# 9                    JPD2017/137/AK    Jelgavas pilsētas dome
#
#    Pasutitaja_registracijas_numurs  \
# 0                      90000077325
# ..                             ...
# 9                      90000042516
#
#                 Pasutitaja_registracijas_numura_veids  \
# 0   Personas kods/nodokļu maksātāja reģistrācijas ...
# ..                                                ...
# 9   Personas kods/nodokļu maksātāja reģistrācijas ...
#
#                                Uzvaretaja_nosaukums  \
# ...

# %%
csv_file2 = 'https://data.gov.lv/dati/dataset/e909312a-61c9-4cde-a72a-0a09dd75ef43/resource/8e004700-c5b7-4307-b037-678be0d8460c/download/eis_e_iepirkumi_rezultati_2023.csv'
df2 = pd.read_csv(csv_file2,sep=';')

# %%
df2
# Out:
#        Iepirkuma_ID                                Iepirkuma_nosaukums  \
# 0              8280  Par servertehnikas piegādi Elektronisko iepirk...
# ...             ...                                                ...
# 42528        114574  Profesionālo medicīnisko displeju un videokarš...
#
#       Iepirkuma_identifikacijas_numurs  \
# 0                VRAA 2014/41/AK/CI-92
# ...                                ...
# 42528             RAKUS 2023/141S/ERAF
#
#                                  Pasutitaja_nosaukums  \
# 0               Valsts reģionālās attīstības aģentūra
# ...                                               ...
# 42528  Rīgas Austrumu klīniskā universitātes slimnīca
#
#        Pasutitaja_registracijas_numurs  \
# 0                          90001733697
# ...                                ...
# 42528                      40003951628
#
#                    Pasutitaja_registracijas_numura_veids  Pasutitaja_PVS_ID  \
# ...

# %%
df2.columns
# Out:
# Index(['Iepirkuma_ID', 'Iepirkuma_nosaukums',
#        'Iepirkuma_identifikacijas_numurs', 'Pasutitaja_nosaukums',
#        'Pasutitaja_registracijas_numurs',
#        'Pasutitaja_registracijas_numura_veids', 'Pasutitaja_PVS_ID',
#        'Augstak_stavosa_organizacija', 'Iepirkuma_statuss',
#        'Regulejasais_tiesibu_akts', 'Proceduras_veids',
#        'Hipersaite_EIS_kura_pieejams_zinojums',
#        'Hipersaite_uz_IUB_publikaciju', 'Ir_dalijums_dalas',
#        'Iepirkuma_dalas_nr', 'Iepirkuma_dalas_nosaukums',
#        'Iepirkuma_dalas_statuss', 'Uzvaretaja_nosaukums',
#        'Uzvaretaja_registracijas_numurs',
#        'Uzvaretaja_registracijas_numura_veids', 'Uzvaretaja_valsts',
#        'Liguma_dok_veids', 'Noslegta_liguma_dok_ID', 'Saistita_liguma_ID',
#        'Aktuala_liguma_summa', 'Aktuala_liguma_summas_valuta',
#        'Sakotneja_liguma_summa', 'Sakotneja_liguma_summas_valuta',
#        'Liguma_izpildes_termins', 'Liguma_izpilde_no', 'Liguma_izpilde_līdz',
# ...

# %%
df2 = df2[['Iepirkuma_ID', 'Iepirkuma_nosaukums','Iepirkuma_identifikacijas_numurs', 'Pasutitaja_nosaukums','Pasutitaja_registracijas_numurs','Pasutitaja_registracijas_numura_veids','Uzvaretaja_nosaukums','Uzvaretaja_registracijas_numurs','Uzvaretaja_registracijas_numura_veids', 'Uzvaretaja_valsts','Aktuala_liguma_summa', 'Aktuala_liguma_summas_valuta','Sakotneja_liguma_summa', 'Sakotneja_liguma_summas_valuta','Liguma_izpilde_no','Liguma_izpilde_līdz']]

# %%
df2.columns
# Out:
# Index(['Iepirkuma_ID', 'Iepirkuma_nosaukums',
#        'Iepirkuma_identifikacijas_numurs', 'Pasutitaja_nosaukums',
#        'Pasutitaja_registracijas_numurs',
#        'Pasutitaja_registracijas_numura_veids', 'Uzvaretaja_nosaukums',
#        'Uzvaretaja_registracijas_numurs',
#        'Uzvaretaja_registracijas_numura_veids', 'Uzvaretaja_valsts',
#        'Aktuala_liguma_summa', 'Aktuala_liguma_summas_valuta',
#        'Sakotneja_liguma_summa', 'Sakotneja_liguma_summas_valuta',
#        'Liguma_izpilde_no', 'Liguma_izpilde_līdz'],
#       dtype='object')

# %%
df2.columns = df2.columns.str.strip()

# %%
df['YEAR'] = 2021

# %%
df2
# Out:
#        Iepirkuma_ID                                Iepirkuma_nosaukums  \
# 0              8280  Par servertehnikas piegādi Elektronisko iepirk...
# ...             ...                                                ...
# 42528        114574  Profesionālo medicīnisko displeju un videokarš...
#
#       Iepirkuma_identifikacijas_numurs  \
# 0                VRAA 2014/41/AK/CI-92
# ...                                ...
# 42528             RAKUS 2023/141S/ERAF
#
#                                  Pasutitaja_nosaukums  \
# 0               Valsts reģionālās attīstības aģentūra
# ...                                               ...
# 42528  Rīgas Austrumu klīniskā universitātes slimnīca
#
#        Pasutitaja_registracijas_numurs  \
# 0                          90001733697
# ...                                ...
# 42528                      40003951628
#
#                    Pasutitaja_registracijas_numura_veids  \
# 0      Personas kods/nodokļu maksātāja reģistrācijas ...
# ...

# %%
df.shape[0]+df2.shape[0]
# Out:
# 67452

# %%
pd.concat([df,df2])
# Out:
#        Iepirkuma_ID                                Iepirkuma_nosaukums  \
# 0              9246  Būvniecības dokumentācijas izstrāde ielu, auto...
# ...             ...                                                ...
# 42528        114574  Profesionālo medicīnisko displeju un videokarš...
#
#       Iepirkuma_identifikacijas_numurs  \
# 0                         DPD 2017/123
# ...                                ...
# 42528             RAKUS 2023/141S/ERAF
#
#                                  Pasutitaja_nosaukums  \
# 0                            Daugavpils pilsētas dome
# ...                                               ...
# 42528  Rīgas Austrumu klīniskā universitātes slimnīca
#
#       Pasutitaja_registracijas_numurs  \
# 0                         90000077325
# ...                               ...
# 42528                     40003951628
#
#                    Pasutitaja_registracijas_numura_veids  \
# 0      Personas kods/nodokļu maksātāja reģistrācijas ...
# ...

# %%
df_papildus = pd.DataFrame(df2['Pasutitaja_registracijas_numurs'].value_counts())
df_papildus
# Out:
#                                  count
# Pasutitaja_registracijas_numurs
# 40003466281                       2988
# ...                                ...
# 40008017804                          1
#
# [514 rows x 1 columns]

# %%
df_papildus.columns
# Out:
# Index(['count'], dtype='object')

# %%
df_papildus = df_papildus.rename(columns = {'Pasutitaja_registracijas_numurs':'iepirkumu_skaits_2023'})

# %%
df_papildus
# Out:
#                                  count
# Pasutitaja_registracijas_numurs
# 40003466281                       2988
# ...                                ...
# 40008017804                          1
#
# [514 rows x 1 columns]
